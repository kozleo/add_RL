# %%
cd /rdma/vast-rdma/vast/fiete/leokoz8/code/add_RL
# Out:
# /rdma/vast-rdma/vast/fiete/leokoz8/code/add_RL

# %%
import numpy as np
import matplotlib.pyplot as plt
from src import utils
from tqdm import tqdm
# %load_ext autoreload
# %autoreload 2

# %%
def update_Q_function(Q,s,s_prime,a,r,gamma,alpha):

    delta = r + gamma*np.max(Q[s_prime,:]) - Q[s,a]
    Q[s,a] += alpha*delta
    
    return Q

def update_Q_and_E(Q,E,s,s_prime,a,r,gamma,alpha,lam,d):
    delta = r + gamma*np.max(Q[s_prime,:]) - Q[s,a]
    delta_drug = delta
    #delta = r + gamma*Q[s_prime,a_prime] - Q[s,a]
    E[s,a] += 1
    
    Q += alpha*delta_drug*E
    E = E*gamma*lam 
    
    return Q,E

def epsilon_greedy_policy(s,Q,epsilon,num_actions):
    if np.random.uniform(0,1) > epsilon:
        a = np.argmax(Q[s,:])            
    else:
        a = np.random.choice(np.arange(num_actions))
        
    return a

def step(s,a):
    
    if s == 0 and a == 0:
        drug_press = True
    else:
        drug_press = False
    
    s_prime = 1       
    
        
    return s_prime, drug_press

# %%
# States
# 0 - Lever Available
# 1 - ISI


# Actions
# 0 - Press Drug Lever
# 1 - Press Sugar Lever
# 2 - Scratch Butt
# 3 - Groom
# ...

nActions = 10
nStates = 2



Q = np.zeros((nStates,nActions))
E = np.zeros((nStates,nActions))
rewards = np.random.uniform(size = (nStates,nActions))

#sugar lever should be off during ISI and high during lever
rewards[1,1] = 0
rewards[0,1] = 2
#drug reward will be time-varying thing with delay
rewards[:,0] = 0
rewards[0,0] = 0

epsilon = 0.5


#pick initial action at lever time
#a = epsilon_greedy_policy(s,Q,epsilon,nActions)

    
T = 30
num_episodes = 1000
tau = 0.3
k = 10 #drug impact
gamma = 1
alpha = 0.001
lam = 0.9
ds = np.zeros(T)
rs = np.zeros(num_episodes)

prob_of_drug_press = 0
prob_of_random_choice = 1/nActions

actions_taken_at_lever = np.zeros((num_episodes,nActions))


for episode in range(num_episodes):
    
    #do update for t = 0, which is when the lever is available
    
    s = 0     
    
    a = epsilon_greedy_policy(s, Q, epsilon, nActions)
    
    actions_taken_at_lever[episode,a] = 1
    
    r = rewards[s,a]
    
    Q, E = update_Q_and_E(Q = Q, E = E, s = 0 , s_prime = 0, a = a, r = r, gamma = gamma, alpha = alpha, lam = lam, d = 0)
    
 
    if a == 0:
        drug_press = True    
        prob_of_drug_press += 1/num_episodes

        
    else:
        drug_press = False    
        

    s_prime = 1   
    
    r_ep = 0
    
    s = 1 
    s_prime = 1
    

    for t in range(T): 

        if drug_press:
            #slow dopamine release
            d = k*tau*t*np.exp(-tau*t)
        else:
            d = 0

        a = epsilon_greedy_policy(s, Q, epsilon, nActions)
        

        #s_prime, drug_press = step(s,a)


        #ds[t] = d


        r = rewards[s,a] + d
        r_ep += r

        Q , E = update_Q_and_E(Q,E,s,s_prime,a,r,gamma,alpha,lam,d)
        
        

    rs[episode] = r_ep    
    
    

        
    
    #s_prime, r, terminated, truncated, info = env.step(a)
    
    
    
  
    
        
#plt.plot(np.cumsum(drug_presses))  

liklihood_ratio = prob_of_drug_press/prob_of_random_choice

print(f'{liklihood_ratio} times more likely to press drug lever.')
# Out:
# 0.42000000000000026 times more likely to press drug lever.

# %%
actions_cum_sum = np.cumsum((actions_taken_at_lever),axis = 0)

plt.plot(actions_cum_sum);

plt.ylabel(r'Cumulative Number of \n Times Actions Taken')
plt.xlabel('Episode Number')
# Out:
# Text(0.5, 0, 'Episode Number')

# %%
import gymnasium as gym
env = gym.make("FrozenLake-v1",render_mode = "rgb_array",map_name="4x4")
action_size = env.action_space.n
state_size = env.observation_space.n

T = int(100)
total_episodes = 60000
#to animate
frames = []


#epsilon greedy
max_epsilon = 1
min_epsilon = 0.01
decay_rate = 1e-3

gamma = 0.95
learning_rate = 0.1
lam = 0.9


#initialize Q function and eligibility traces
Q = np.zeros((state_size,action_size))
E = np.zeros((state_size,action_size))

# List of rewards
rewards = []

# For life or until learning is stopped
for episode in tqdm(range(total_episodes)):
    
    # Reset the environment
    s, info = env.reset(seed=42)
    step = 0
    total_rewards = 0
    a_prime = 0 
    
    # Reduce epsilon (because we need less and less exploration)    
    epsilon = min_epsilon + (max_epsilon - min_epsilon)*np.exp(-decay_rate*episode) 


    for t in range(T):

        a = epsilon_greedy_policy(env,Q,epsilon)
            

        s_prime, r, terminated, truncated, info = env.step(a)

        Q,E = update_Q_and_E(Q,E,s,s_prime,a,a_prime,r,gamma,learning_rate,lam)
        
        assert np.linalg.norm(Q) <= 1e3, print('Bad--Q explosion!')

        s = s_prime
        #a = a_prime

        total_rewards += r
        
        es.append(np.linalg.norm(E))


        #uncomment to store frames for animation
        #frames.append(env.render())


        if terminated or truncated:
            break          
        
    
    rewards.append(total_rewards)
env.close()

print ("Score over time: " +  str(sum(rewards)/total_episodes))
# Out:
# 100%|██████████| 60000/60000 [00:49<00:00, 1220.40it/s]
# Score over time: 0.9289833333333334

# %%
plt.imshow(env.render())

# %%
np.max(E)
# Out:
# 1.3943821939533123

# %%
plt.plot(np.cumsum(rewards))

# %%
env.reset()
frames = []

for episode in range(10):
    
    s,info = env.reset(seed=42)

    for step in range(T):
        
        # Take the action (index) that have the maximum expected future reward given that state
        a = np.argmax(Q[s,:])
        
        s_prime, r, terminated, truncated, info = env.step(a)
        frames.append(env.render())
        if terminated or truncated:
            break
        s = s_prime
env.close()

utils.save_frames_as_gif(frames)
# Out:
# Remaining number of frames : 70
# Remaining number of frames : 70
# Remaining number of frames : 69
# Remaining number of frames : 68
# Remaining number of frames : 67
# Remaining number of frames : 66
# Remaining number of frames : 65
# Remaining number of frames : 64
# Remaining number of frames : 63
# Remaining number of frames : 62
# Remaining number of frames : 61
# Remaining number of frames : 60
# Remaining number of frames : 59
# Remaining number of frames : 58
# Remaining number of frames : 57
# Remaining number of frames : 56
# Remaining number of frames : 55
# Remaining number of frames : 54
# Remaining number of frames : 53
# Remaining number of frames : 52
# Remaining number of frames : 51
# Remaining number of frames : 50
# Remaining number of frames : 49
# Remaining number of frames : 48
# Remaining number of frames : 47
# Remaining number of frames : 46
# Remaining number of frames : 45
# Remaining number of frames : 44
# Remaining number of frames : 43
# ...

# %%
    def sarsa_lambda(env, num_episodes, discount=0.9, alpha=0.01, trace_decay=0.9, epsilon=0.1, type='accumulate'):
    
        Q = defaultdict(lambda: np.zeros(env.nA))
        E = defaultdict(lambda: np.zeros(env.nA))
    
    
        for i_episode in range(num_episodes):
    
            print("\rEpisode {}/{}. ({})".format(i_episode+1, num_episodes, rewards[-1]), end="")
            sys.stdout.flush()
    
            state = env.reset()
            action_probs = policy(state)
            action = np.random.choice(np.arange(len(action_probs)), p=action_probs)
    
            for t in itertools.count():
    
                next_state, reward, done, _ = env.step(action)
    
                next_action_probs = policy(next_state)
                next_action = np.random.choice(np.arange(len(next_action_probs)), p=next_action_probs)
    
                delta = reward + discount*Q[next_state][next_action] - Q[state][action]
    
                stats.episode_rewards[i_episode] += reward
    
                E[state][action] += 1
    
                for s, _ in Q.items():
                    Q[s][:] += alpha * delta * E[s][:]
                    if type == 'accumulate':
                        E[s][:] *= trace_decay * discount
                    elif type == 'replace':
                        if s == state:
                            E[s][:] = 1
                        else:
                            E[s][:] *= discount * trace_decay
    
                if done:
                    break
    
                state = next_state
                action = next_action
    
        return Q, stats
